# %%
#General purpose packages for data processing
import pandas as pd
import sklearn

# %%
#Collecting data from all systems, only showing controller, CPU%, CPU Time, and Memory Usage
columns_to_extract = ['Controller', 'CPU %', 'CPU Time', 'Memory Usage']
all_data = pd.read_csv('../ics_metrics.csv', usecols=columns_to_extract)

#Collecting specific sets for each system
weapons_data = all_data[all_data['Controller'] == 'weapons']
navigation_data = all_data[all_data['Controller'] == 'navigation']
propulsion_data = all_data[all_data['Controller'] == 'propulsion']
power_data = all_data[all_data['Controller'] == 'power']

# %%
#showing weapons data for example
weapons_data
# Out:
#     Controller      CPU %     CPU Time  Memory Usage
# 0      weapons  14.564451  4309.757443    591.957583
# 4      weapons  13.876101  4312.943008    552.742861
# 8      weapons  14.162473  4317.449086    563.152433
# 12     weapons  14.617581  4319.370407    603.965759
# 16     weapons  14.825561  4321.185232    614.494077
# 20     weapons  14.063754  4323.132832    603.547055
# 24     weapons  14.121852  4326.162899    632.578720
# 28     weapons  14.076613  4329.540148    611.016076
# 32     weapons  13.537846  4332.786967    624.463264
# 36     weapons  13.740930  4336.885815    656.990700
# 40     weapons  13.532719  4340.009735    697.388417
# 45     weapons  13.740568  4344.132598    687.107963
# 49     weapons  13.589839  4347.643095    712.063016
# 55     weapons  14.404574  4350.523747    744.064633
# 57     weapons  15.136973  4351.663422    708.057851
# 63     weapons  15.734324  4355.221495    720.762364
# 67     weapons  16.349503  4358.907327    735.086239
# 71     weapons  17.070405  4360.873244    749.097959
# 75     weapons  17.766259  4364.536595    774.382986
# 79     weapons  18.036583  4372.433550    815.711229
# 83     weapons  17.778543  4374.616674    838.192835
# 86     weapons  17.398444  4377.264366    837.995403
# 90     weapons  16.530646  4379.005935    809.930434
# 96     weapons  17.472773  4380.531216    821.811497
# 100    weapons  17.527981  4385.110462    869.489053
# 104    weapons  16.531148  4389.938708    900.440872
# 107    weapons  15.784269  4392.317914    900.428245
# 112    weapons  15.641968  4395.239971    854.127004
# 116    weapons  16.015759  4399.048253    875.359072
# 120    weapons  15.268650  4400.444580    863.928931
# 125    weapons  14.425763  4402.601070    869.661285
# 127    weapons  13.747284  4404.040264    820.278524
# 131    weapons  14.190400  4406.660745    777.081057
# 135    weapons  15.141615  4410.101476    800.546993
# 139    weapons  14.855706  4413.345943    755.363206
# 142    weapons  14.337431  4418.249841    799.562687
